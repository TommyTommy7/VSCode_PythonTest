# %%
import matplotlib.pyplot as plt

flg, ax = plt.subplots()
ax.plot([2,1,,3])
# Out:
#   File "<ipython-input-1-a738aed1a03e>", line 5
#     ax.plot([2,1,,3])
#                  ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

flg, ax = plt.subplots()
ax.plot([2,1,3])
